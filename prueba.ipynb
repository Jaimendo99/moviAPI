# %%
import pandas as pd
import urllib.parse
import requests
import json
import pickle
import re
import ast
from datetime import datetime

# %%
import requests

url = "https://fullstack.movistar.com.ec/rest/UIPlugins/WidgetRequestProcessor/process"

payload = '''
request=%7B%22requests%22%3A%5B%7B%22path%22%3A%22%2Frest%2FUIPlugins%2FCtrl%2Frefresh%22%2C%22body%22%3A%22%7B%5C%22dataParams%5C%22%3A%7B%7D%2C%5C%22c%5C%22%3A%5C%22com.netcracker.platform.ui.plugins.rest.service.transport.request.TableCtrlRequest%5C%22%2C%5C%22dsName%5C%22%3A%5C%22BusinessCustomerSearchResultsDS%5C%22%2C%5C%22functions%5C%22%3Anull%2C%5C%22filteringDescriptor%5C%22%3A%7B%5C%22c%5C%22%3A%5C%22com.netcracker.platform.ui.plugins.gwt.tablectrl.shared.transport.filtering.FilteringDescriptor%5C%22%2C%5C%22filters%5C%22%3A%7B%7D%7D%2C%5C%22pagingDescriptor%5C%22%3A%7B%5C%22fullscreenCount%5C%22%3A50%2C%5C%22c%5C%22%3A%5C%22com.netcracker.platform.ui.plugins.gwt.tablectrl.shared.transport.RequestPagingDescriptor%5C%22%2C%5C%22count%5C%22%3A200%2C%5C%22from%5C%22%3A0%7D%2C%5C%22requestParams%5C%22%3A%7B%5C%22modal_grid_panel%5C%22%3A%5C%22true%5C%22%2C%5C%22mergedWidgetContainerId%5C%22%3Anull%2C%5C%22SearchDescriptor%5C%22%3A%7B%5C%22configObjectId%5C%22%3A%5C%229148020355713499946%5C%22%2C%5C%22searchCriterion%5C%22%3A%5B%7B%5C%22c%5C%22%3A%5C%22com.netcracker.platform.ui.plugins.gwt.search.shared.transport.SearchCriteria%5C%22%2C%5C%22attributeId%5C%22%3A%5C%229147380538313775291%5C%22%2C%5C%22searchProfileId%5C%22%3A%5C%229145173674713662254%5C%22%2C%5C%22searchRule%5C%22%3A%7B%5C%22c%5C%22%3A%5C%22com.netcracker.platform.ui.plugins.gwt.search.shared.transport.field.SearchRule%5C%22%2C%5C%22code%5C%22%3A%5C%22in%5C%22%2C%5C%22text%5C%22%3A%5C%22contiene%5C%22%7D%2C%5C%22values%5C%22%3A%5B%5C%2213122429%5C%22%5D%2C%5C%22searchMask%5C%22%3A%5C%22*%5C%22%7D%5D%2C%5C%22resetDefaultUserView%5C%22%3Atrue%2C%5C%22searchOptions%5C%22%3A%7B%5C%22isCaseSensitive%5C%22%3Afalse%2C%5C%22isUseWildcards%5C%22%3Afalse%2C%5C%22isSearchScopeEnabled%5C%22%3Afalse%2C%5C%22isSearchScopeCollapsed%5C%22%3Afalse%7D%2C%5C%22c%5C%22%3A%5C%22com.netcracker.platform.ui.plugins.gwt.search.shared.transport.SearchDescriptor%5C%22%7D%2C%5C%22searchResultsCoreDsId%5C%22%3A%5C%229135689049113520640%5C%22%2C%5C%22pageContext%5C%22%3A%5B%7B%5C%22name%5C%22%3A%5C%22cfadmin%5C%22%2C%5C%22value%5C%22%3A%5C%22ZARV-7pRz-Rg72-f4Lb-ynHQ-MqUv%5C%22%7D%5D%2C%5C%22dashboardID%5C%22%3A%5C%229148029260113987468%5C%22%2C%5C%22searchResultsDsName%5C%22%3A%5C%22BusinessCustomerSearchResultsDS%5C%22%2C%5C%22searchResultsWcId%5C%22%3A%5C%229148020328713499842%5C%22%2C%5C%22customizationColumnNumberEnabled%5C%22%3A%5C%22true%5C%22%2C%5C%22class%5C%22%3A%5C%22com.netcracker.cihm.web.server.widget.CIHMGWTWidget%5C%22%2C%5C%22objectId%5C%22%3A%5C%229134256259513156680%5C%22%2C%5C%22height%5C%22%3A%5C%22auto%5C%22%2C%5C%22valuablePageSize%5C%22%3A%5C%22%5C%22%2C%5C%22customizationEnabled%5C%22%3A%5C%22false%5C%22%2C%5C%
escriptor%5C%22%3A%7B%5C%22c%5C%22%3A%5C%22com.netcracker.platform.ui.plugins.gwt.tablectrl.shared.transport.SortingDescriptor%5C%22%2C%5C%22sortings%5C%22%3A%7B%7D%7D%2C%5C%22parentPK%5C%22%3Anull%2C%5C%22objectPKs%5C%22%3A%5B%5C%22java.math.BigInteger%3A%7Bmot%3A9134256259513156651%3Bmas%3A1%3Bcontent%3A9134256259513156680%7D%5C%22%5D%7D%22%2C%22c%22%3A%22com.netcracker.platform.ui.plugins.gwt.common.shared.transport.widget.request.WidgetTransportRequest%22%7D%5D%2C%22groupTimeout%22%3A%22100000%22%2C%22c%22%3A%22com.netcracker.platform.ui.plugins.gwt.common.shared.transport.widget.request.WidgetTransportGroupRequest%22%7D
'''

headers = {
  'Cookie': 'LastMRH_Session=99df58a2; TIN=272000; F5_ST=1z1z1z1735577179z36000; MRHSession=ca31a512c4f99436953b824b19271ae2; JSESSIONID=Fy0Yd8Hm8lqkypVSbenCbwIyvLiLglYt6k5BrHsVxMWRCGr_LdXt!159041773; latency-info=eyJjb21wbGV0ZWQiOmZhbHNlfQ==; bandwidth-info=eyJjb21wbGV0ZWQiOmZhbHNlLCJiYW5kd2lkdGhJbWFnZXMiOnt9fQ==; nc.esc.tid=pmnjkj7laqw5; LastMRH_Session=19271ae2',
  'cfadmin': 'WMWI-jfHu-lHJm-5scV-0CoD-0SNX',
}

# response = requests.request("POST", url, headers=headers, data=payload)

# print(response.text)

# %%
with open('searchPayload.txt', 'w') as f:
    f.write(payload)

# %%
with open('searchPayload.txt', 'r') as f:
    payload = f.read()

# %%
def decode_payload(payload:str)->dict:
    raw_payload = payload.split("request=", 1)[1]
    decoded = urllib.parse.unquote(raw_payload)
    parsed_top = json.loads(decoded)
    first_request = parsed_top["requests"][0]
    body_str = first_request["body"]
    body_dict = json.loads(body_str)
    first_request["body"] = body_dict
    return parsed_top


def encode_payload(payload: dict) -> str:
    for req in payload.get("requests", []):
        body_value = req.get("body")
        if isinstance(body_value, dict):
            req["body"] = json.dumps(body_value)

    top_level_json = json.dumps(payload)
    url_encoded = urllib.parse.quote(top_level_json)

    return f"request={url_encoded}"

# %%
search_field_id = {
    'phone_number':'9146583874513687177',
    'id_number':'9147380538313775291',
    'names':'9132121613813866299'
}

search_rules = {
    'contiene':'in',
    'termina con':'ew',
    'se inicia con':'sw',
    'igual':'eq'
}

searchs = {
    'phone_number':{
        'value':'',
        'rule':'igual'
    },
    'id_number':{
        'value':'131224',
        'rule':'contiene'
    },
    'names':{
        'value':'',
        'rule':'contiene'
    }
}


searchCriteria = {
    'c': 'com.netcracker.platform.ui.plugins.gwt.search.shared.transport.SearchCriteria',
    'attributeId': '',
    'searchProfileId': '9145173674713662254',
    'searchRule': {
        'c': 'com.netcracker.platform.ui.plugins.gwt.search.shared.transport.field.SearchRule',
        'code': '',
        'text': ''
    },
    'values': [''],
    'searchMask': '*'
}

searchCriterias = []
for key, value in searchs.items():
    searchCriteria_copy = searchCriteria.copy()
    if not value['value']:
        continue
    searchCriteria_copy['attributeId'] = search_field_id[key]
    searchCriteria_copy['searchRule']['code'] = search_rules[value['rule']]
    searchCriteria_copy['searchRule']['text'] = value['rule']
    searchCriteria_copy['values'] = [value['value']]
    searchCriterias.append(searchCriteria_copy)

searchCriterias
# Out:
# [{'c': 'com.netcracker.platform.ui.plugins.gwt.search.shared.transport.SearchCriteria',
#   'attributeId': '9147380538313775291',
#   'searchProfileId': '9145173674713662254',
#   'searchRule': {'c': 'com.netcracker.platform.ui.plugins.gwt.search.shared.transport.field.SearchRule',
#    'code': 'in',
#    'text': 'contiene'},
#   'values': ['131224'],
#   'searchMask': '*'}]

# %%
parsed_top['requests'][0]['body']['requestParams']['SearchDescriptor']['searchCriterion'] = searchCriterias

# %%
parsed_top['requests'][0]['body']['pagingDescriptor']['count']=500

# %%
with open('data.json', 'r') as f:
    data = json.load(f)

# %%
body = json.loads(data['responses'][0]['body'])

# %%
# name_locator = ['data']['-1']['v']['text']
# id_number_locator = ['data']['9144718640113557588']['v']

# %%
clients_df = pd.DataFrame(columns=['client_id', 'name', 'id_number', 'phone_number', 'phone_status', 'contextId'])
for key, value in body['data'].items():
    name = value['data']['-1']['v']['text']
    id_number = value['data']['9144718640113557588']['v']
    nombers = value['data']['9145139830513734387']
    client_id = key[-20:-1]
    if nombers:
        for phone_object in nombers['v']:
            phone_number = phone_object['text']
            phone_status = phone_object['line_status_text']
            contextId = phone_object['line_id'][-13:len(phone_object['line_id'])]
            client_row = pd.DataFrame({'client_id':client_id, 'name':name, 'id_number':id_number, 'phone_number':phone_number, 'phone_status':phone_status, 'contextId':contextId}, index=[0])
            clients_df = pd.concat([clients_df, client_row], ignore_index=True)
    else:
        client_row = pd.DataFrame({'client_id':client_id, 'name':name, 'id_number':id_number, 'phone_number':'', 'phone_status':'', 'contextId':''}, index=[0])
        clients_df = pd.concat([clients_df, client_row], ignore_index=True)

# %%
client_detail_req_body = 'request=%7B%22requests%22%3A%5B%7B%22path%22%3A%22%2Frest%2FUIPlugins%2FComposite%2Fconfig%22%2C%22body%22%3A%22%7B%5C%22dsName%5C%22%3A%5C%22WidgetCompositeDS%5C%22%2C%5C%22parentPK%5C%22%3A%5C%22java.math.BigInteger%3A%7Bmot%3A9134256259513156651%3Bmas%3A1%3Bcontent%3A9134256259513156680%7D%5C%22%2C%5C%22objectPKs%5C%22%3A%5B%5C%22java.math.BigInteger%3A%7Bmot%3A0%3Bmas%3A1%3Bcontent%3A9151120348613416921%7D%5C%22%5D%2C%5C%22requestParams%5C%22%3A%7B%5C%22widgetContainerId%5C%22%3A%5C%229145863890013911270%5C%22%2C%5C%22wcID%5C%22%3A%5C%229145863890013911270%5C%22%2C%5C%22ncObjectID%5C%22%3A%5C%229151120348613416921%5C%22%2C%5C%22ticketDraftId%5C%22%3A%5C%229171848644713037291%5C%22%2C%5C%22widgetClass%5C%22%3A%5C%22com.netcracker.solutions.tfnecu.csrd.gwt.client.ctrl.composite.TicketPanelCtrl%5C%22%2C%5C%22initializationParams%5C%22%3A%7B%5C%22wcID%5C%22%3A%5C%229145863890013911270%5C%22%2C%5C%22ncObjectID%5C%22%3A%5C%229151120348613416921%5C%22%2C%5C%22ticketDraftId%5C%22%3A%5C%229171848644713037291%5C%22%2C%5C%22widgetClass%5C%22%3A%5C%22com.netcracker.solutions.tfnecu.csrd.gwt.client.ctrl.composite.TicketPanelCtrl%5C%22%7D%2C%5C%22urlParams%5C%22%3A%7B%7D%2C%5C%22isLazy%5C%22%3Afalse%2C%5C%22lazyLoadNum%5C%22%3A0%2C%5C%22lazyRenderNum%5C%22%3A0%7D%2C%5C%22c%5C%22%3A%5C%22com.netcracker.platform.ui.plugins.rest.service.transport.request.CompositeWidgetsRequest%5C%22%7D%22%2C%22c%22%3A%22com.netcracker.platform.ui.plugins.gwt.common.shared.transport.widget.request.WidgetTransportRequest%22%7D%5D%2C%22groupTimeout%22%3A%22100000%22%2C%22c%22%3A%22com.netcracker.platform.ui.plugins.gwt.common.shared.transport.widget.request.WidgetTransportGroupRequest%22%7D'

# %%
client_detail_body = decode_payload(client_detail_req_body)

# %%
def get_objectPK(client_id:str)->str:
    return f"java.math.BigInteger:{{mot:0;mas:1;content:{client_id}}}"

# %%
client_id = "9149095205913670700"
context_id = '1xn5s8rlz6hld'
client_detail_body['requests'][0]['body']['objectPKs']  = [get_objectPK(client_id)]
client_detail_body['requests'][0]['body']['requestParams']['ncObjectID'] = client_id
client_detail_body['requests'][0]['body']['requestParams']['initializationParams']['ncObjectID'] = client_id

# %%
client_detail_body['requests'][0]['body']['requestParams']['contextId'] = context_id

# %%
client_body_raw = encode_payload(client_detail_body.copy())
client_body_raw
# Out:
# 'request=%7B%22requests%22%3A%20%5B%7B%22path%22%3A%20%22/rest/UIPlugins/Composite/config%22%2C%20%22body%22%3A%20%22%7B%5C%22dsName%5C%22%3A%20%5C%22WidgetCompositeDS%5C%22%2C%20%5C%22parentPK%5C%22%3A%20%5C%22java.math.BigInteger%3A%7Bmot%3A9134256259513156651%3Bmas%3A1%3Bcontent%3A9134256259513156680%7D%5C%22%2C%20%5C%22objectPKs%5C%22%3A%20%5B%5C%22java.math.BigInteger%3A%7Bmot%3A0%3Bmas%3A1%3Bcontent%3A9149095205913670700%7D%5C%22%5D%2C%20%5C%22requestParams%5C%22%3A%20%7B%5C%22widgetContainerId%5C%22%3A%20%5C%229145863890013911270%5C%22%2C%20%5C%22wcID%5C%22%3A%20%5C%229145863890013911270%5C%22%2C%20%5C%22ncObjectID%5C%22%3A%20%5C%229149095205913670700%5C%22%2C%20%5C%22ticketDraftId%5C%22%3A%20%5C%229171848644713037291%5C%22%2C%20%5C%22widgetClass%5C%22%3A%20%5C%22com.netcracker.solutions.tfnecu.csrd.gwt.client.ctrl.composite.TicketPanelCtrl%5C%22%2C%20%5C%22initializationParams%5C%22%3A%20%7B%5C%22wcID%5C%22%3A%20%5C%229145863890013911270%5C%22%2C%20%5C%22ncObjectID%5C%22%3A%2
# ...

# %%
with open('data1.json', 'r') as f:
    client_detail_res = json.load(f)

# %%
client_res_body = json.loads(client_detail_res['responses'][0]['body'])

# %%
with open('data2.json', 'r') as f:
    line_detail_res = json.load(f)

# %%
line_detail_body = json.loads(line_detail_res['responses'][0]['body'])

# %%
import json
import requests

url = "https://fullstack.movistar.com.ec/csrd/rest/api/data/page"

# 1. Convert the payload string into a Python dictionary
raw_payload = {
  "loadedWidgetsData": [
    "com.netcracker.csrdesktop.spa.shared.dto.SectionsDto",
    "com.netcracker.csrdesktop.spa.shared.dto.SearchPageContentDto"
  ],
  "pageDataRequest": {
    "pageHost": "/csrdesktop/csrdesktop.jsp",
    "pageToken": "!board",
    "params": {
      "customerId": "9149095205913670700",
      "contextId": "1xn5s8rlz6hld"
    },
    "clientTimeMillis": "1735595157950"
  },
  "previousPageDataRequest": {
    "pageHost": "/csrdesktop/csrdesktop.jsp",
    "pageToken": "!search",
    "clientTimeMillis": "1735594943485"
  },
  "businessExceptions": [
    "NeedChangeCustomerException",
    "UnknownCustomerException"
  ]
}

payload_dict = json.loads(raw_payload)

headers = {
  'Content-Type': 'application/json; charset=UTF-8',
  'Cookie': 'LastMRH_Session=19271ae2; TIN=282000; F5_ST=1z1z1z1735577179z36000; MRHSession=ca31a512c4f99436953b824b19271ae2; JSESSIONID=Fy0Yd8Hm8lqkypVSbenCbwIyvLiLglYt6k5BrHsVxMWRCGr_LdXt!159041773; latency-info=eyJjb21wbGV0ZWQiOmZhbHNlfQ==; bandwidth-info=eyJjb21wbGV0ZWQiOmZhbHNlLCJiYW5kd2lkdGhJbWFnZXMiOnt9fQ==; nc.esc.tid=waboo8a90kjd',
  'cfadmin': 'WMWI-jfHu-lHJm-5scV-0CoD-0SNX'
}

# 2. Pass the dict via the `json` parameter instead of data=...
response = requests.post(url, headers=headers, json=payload_dict)

print(response.text)

# %%
payload = 'request=%7B%22requests%22%3A%5B%7B%22path%22%3A%22%2Frest%2FUIPlugins%2FCtrl%2Frefresh%22%2C%22body%22%3A%22%7B%5C%22dsName%5C%22%3A%5C%22TableCtrlDynamicFetchPlanDS%5C%22%2C%5C%22objectPKs%5C%22%3A%5B%5C%22java.math.BigInteger%3A%7Bmot%3A2091641841013994133%3Bmas%3A1%3Bcontent%3A9149095187413929612%7D%5C%22%5D%2C%5C%22requestParams%5C%22%3A%7B%5C%22checkBoxEnabled%5C%22%3A%5C%22false%5C%22%2C%5C%22customizationEnabled%5C%22%3A%5C%22false%5C%22%2C%5C%22mask_field_resized%5C%22%3A%5C%22true%5C%22%2C%5C%22editable%5C%22%3Afalse%2C%5C%22modal_grid_panel%5C%22%3A%5C%22true%5C%22%2C%5C%22mergedWidgetContainerId%5C%22%3Anull%2C%5C%22gwtClass%5C%22%3A%5C%22com.netcracker.platform.ui.plugins.gwt.tablectrl.client.TableCtrl%5C%22%2C%5C%22hideEditableButton%5C%22%3Atrue%2C%5C%22pageSize%5C%22%3A%5C%2210%5C%22%2C%5C%22coreDsId%5C%22%3A%5C%229157884230013223743%5C%22%2C%5C%22userViewHeaderEnabled%5C%22%3A%5C%22true%5C%22%2C%5C%22title%5C%22%3A%5C%22Cambiar+Historial%5C%22%2C%5C%22requestGrouping%5C%22%3A%5C%22true%5C%22%2C%5C%22pagingEnabled%5C%22%3A%5C%22true%5C%22%2C%5C%22customizationColumnNumberEnabled%5C%22%3A%5C%22true%5C%22%2C%5C%22requestGrouping_name%5C%22%3A%5C%22changeHistory%5C%22%2C%5C%22objectId%5C%22%3A%5C%229149095187413929612%5C%22%2C%5C%22dashboardID%5C%22%3A%5C%229139371752413211527%5C%22%2C%5C%22widgetId%5C%22%3A%5C%229147845456013927759%5C%22%2C%5C%22drawFakeCheckboxes%5C%22%3A%5C%22false%5C%22%2C%5C%22initializationParams%5C%22%3A%7B%5C%22customizeReferenceFields%5C%22%3A%5C%22true%5C%22%2C%5C%22dashboardID%5C%22%3A%5C%229139371752413211527%5C%22%2C%5C%22referenceCustomizer%5C%22%3A%5C%22boardReferenceCustomizer%5C%22%2C%5C%22ncObjectID%5C%22%3A%5C%229149095187413929612%5C%22%2C%5C%22csrdContext%5C%22%3A%7B%5C%22ctx_csrd_section_id%5C%22%3A%5C%22salesOrders%5C%22%2C%5C%22ctx_cihm_line_id%5C%22%3A%5C%229165870086713667710%5C%22%2C%5C%22ctx_csrd_page_token%5C%22%3A%5C%22\u0021board%5C%22%2C%5C%22ctx_csrd_page_params%5C%22%3A%7B%5C%22customerId%5C%22%3A%5C%229149095187413929612%5C%22%2C%5C%22contextId%5C%22%3A%5C%221xmytrvv8qhry%5C%22%2C%5C%22sectionId%5C%22%3A%5C%22salesOrders%5C%22%7D%2C%5C%22ctx_cihm_customer_id%5C%22%3A%5C%229149095187413929612%5C%22%2C%5C%22ctx_csrd_filter_context_id%5C%22%3A%5C%221xmytrvv8qhry%5C%22%2C%5C%22ctx_csrd_page_host%5C%22%3A%5C%22%2Fcsrdesktop%2Fcsrdesktop.jsp%5C%22%2C%5C%22ctx_cihm_billing_account_id%5C%22%3A%5C%229165854367957142725%5C%22%7D%2C%5C%22showOperationsButton%5C%22%3A%5C%22true%5C%22%2C%5C%22drawFakeCheckboxes%5C%22%3A%5C%22false%5C%22%2C%5C%22objectPK%5C%22%3A%5C%22java.math.BigInteger%3A%7Bmot%3A0%3Bmas%3A1%3Bcontent%3A9149095187413929612%7D%5C%22%7D%2C%5C%22pageContext%5C%22%3A%5B%7B%5C%22name%5C%22%3A%5C%22cfadmin%5C%22%2C%5C%22value%5C%22%3A%5C%223xR5-sJFk-A4W4-14ba-LXdY-avI6%5C%22%7D%5D%2C%5C%22widgetContainerId%5C%22%3A%5C%229157884230013223760%5C%22%2C%5C%22urlParams%5C%22%3A%7B%7D%7D%2C%5C%22requestTimeout%5C%22%3A%7B%5C%22c%5C%22%3A%5C%22com.netcracker.platform.ui.plugins.gwt.model.shared.RequestTimeout%5C%22%2C%5C%22timeoutId%5C%22%3A%5C%22HhvqnVdFenLg5qFTnGWhdaYvdbfqAz3DGqHMDoKPqpMl9qZk7w_9157884230013223760%5C%22%2C%5C%22v%5C%22%3A%5C%2220000%5C%22%7D%2C%5C%22pagingDescriptor%5C%22%3A%7B%5C%22c%5C%22%3A%5C%22com.netcracker.platform.ui.plugins.gwt.tablectrl.shared.transport.RequestPagingDescriptor%5C%22%2C%5C%22from%5C%22%3A0%2C%5C%22count%5C%22%3A10%2C%5C%22fullscreenCount%5C%22%3A0%7D%2C%5C%22filteringDescriptor%5C%22%3A%7B%5C%22c%5C%22%3A%5C%22com.netcracker.platform.ui.plugins.gwt.tablectrl.shared.transport.filtering.FilteringDescriptor%5C%22%2C%5C%22filters%5C%22%3A%7B%7D%7D%2C%5C%22c%5C%22%3A%5C%22com.netcracker.platform.ui.plugins.rest.service.transport.request.TableCtrlRequest%5C%22%7D%22%2C%22c%22%3A%22com.netcracker.platform.ui.plugins.gwt.common.shared.transport.widget.request.WidgetTransportRequest%22%7D%5D%2C%22groupTimeout%22%3A%22100000%22%2C%22c%22%3A%22com.netcracker.platform.ui.plugins.gwt.common.shared.transport.widget.request.WidgetTransportGroupRequest%22%7D'

payload = decode_payload(payload)

# %%
payload['requests'][0]['body']['requestParams']['initializationParams']['csrdContext']['ctx_csrd_page_params']['customerId'] = 'JAIME MENDOZA'

# %%
context_id = 'JAIME MENDOZA 2'
payload['requests'][0]['body']['requestParams']['initializationParams']['csrdContext']['ctx_csrd_page_params']['contextId'] = context_id
payload['requests'][0]['body']['requestParams']['initializationParams']['csrdContext']['ctx_csrd_filter_context_id'] = context_id
# Out:
# '1xmytrvv8qhry'

# %%
response = {
    "c": "com.netcracker.platform.ui.plugins.gwt.common.shared.transport.widget.request.WidgetTransportGroupResponse",
    "responses": [
        {
            "c": "com.netcracker.platform.ui.plugins.gwt.common.shared.transport.widget.request.WidgetTransportResponse",
            "body": "{\"metamodel\":{\"c\":\"com.netcracker.platform.ui.plugins.rest.service.transport.metamodel.MetaModel\"},\"c\":\"com.netcracker.platform.ui.plugins.rest.service.transport.response.TableCtrlResponse\",\"data\":{\"java.math.BigInteger:{mot:9062352550013045461;mas:1;content:9167434003662790522}\":{\"data\":{\"9157884418713223833_9126090157513456523\":{\"v\":{\"c\":\"lst\",\"color\":null,\"v\":\"9129643639813420226\",\"obsolete\":null,\"text\":null},\"opk\":\"java.math.BigInteger:{mot:9062352550013045460;mas:1;content:9167430762713523629}\"},\"9157884418713223833_9145589430013662246\":{\"v\":\"1691410436000\",\"opk\":\"java.math.BigInteger:{mot:9062352550013045460;mas:1;content:9167430762713523629}\"},\"9144543752013303034\":{\"v\":{\"c\":\"ref\",\"objectTypeId\":\"9144593476213342411\",\"v\":\"java.math.BigInteger:{mot:9144593476213342411;mas:1;content:9149095238313052468}\",\"icon\":\"/solutions/tfnecu/ri/img/svg/phone_number.svg\",\"text\":\"987740316\",\"objectId\":\"9149095238313052468\",\"url\":\"/csrdesktop/csrdesktop.jsp#!other;customerId=9149095187413929612;contextId=1xmytrvv8qhry;sectionId=salesOrders;objectUrl=L25jb2JqZWN0LmpzcD9pZD05MTQ5MDk1MjM4MzEzMDUyNDY4\"}},\"9072741107013063688\":{\"v\":{\"c\":\"ref\",\"objectTypeId\":\"9126083628313449001\",\"v\":\"java.math.BigInteger:{mot:9126083628313449001;mas:1;content:9165851196313763709}\",\"icon\":\"/skins/arctic/img/ico/types/svg/ico_default.svg\",\"text\":\"PREPAGO TODO EN UNO [987740316]\",\"objectId\":\"9165851196313763709\",\"url\":\"/csrdesktop/csrdesktop.jsp#!board;customerId=9149095187413929612;contextId=1xmytrvv8qhry;sectionId=salesOrders;objectId=9165851196313763709\"}}},\"selectable\":true,\"id\":\"java.math.BigInteger:{mot:9062352550013045461;mas:1;content:9167434003662790522}\"},\"java.math.BigInteger:{mot:9062352550013045461;mas:1;content:9165886776558305402}\":{\"data\":{\"9157884418713223833_9126090157513456523\":{\"v\":{\"c\":\"lst\",\"color\":null,\"v\":\"9129643639813420226\",\"obsolete\":null,\"text\":null},\"opk\":\"java.math.BigInteger:{mot:9062352550013045460;mas:1;content:9165883536513829329}\"},\"9157884418713223833_9145589430013662246\":{\"v\":\"1675938166000\",\"opk\":\"java.math.BigInteger:{mot:9062352550013045460;mas:1;content:9165883536513829329}\"},\"9144543752013303034\":{\"v\":{\"c\":\"ref\",\"objectTypeId\":\"9144593476213342411\",\"v\":\"java.math.BigInteger:{mot:9144593476213342411;mas:1;content:9149095213613991834}\",\"icon\":\"/solutions/tfnecu/ri/img/svg/phone_number.svg\",\"text\":\"994281177\",\"objectId\":\"9149095213613991834\",\"url\":\"/csrdesktop/csrdesktop.jsp#!other;customerId=9149095187413929612;contextId=1xmytrvv8qhry;sectionId=salesOrders;objectUrl=L25jb2JqZWN0LmpzcD9pZD05MTQ5MDk1MjEzNjEzOTkxODM0\"}},\"9072741107013063688\":{\"v\":{\"c\":\"ref\",\"objectTypeId\":\"9126083628313449001\",\"v\":\"java.math.BigInteger:{mot:9126083628313449001;mas:1;content:9165870086713667710}\",\"icon\":\"/skins/arctic/img/ico/types/svg/ico_default.svg\",\"text\":\"PREPAGO TODO EN UNO [994281177]\",\"objectId\":\"9165870086713667710\",\"url\":\"/csrdesktop/csrdesktop.jsp#!board;customerId=9149095187413929612;contextId=1xmytrvv8qhry;sectionId=salesOrders;objectId=9165870086713667710\"}}},\"selectable\":true,\"id\":\"java.math.BigInteger:{mot:9062352550013045461;mas:1;content:9165886776558305402}\"},\"java.math.BigInteger:{mot:9062352550013045461;mas:1;content:9165897642562981172}\":{\"data\":{\"9157884418713223833_9126090157513456523\":{\"v\":{\"c\":\"lst\",\"color\":null,\"v\":\"9129643639813420226\",\"obsolete\":null,\"text\":null},\"opk\":\"java.math.BigInteger:{mot:9062352550013045460;mas:1;content:9165894402213590928}\"},\"9157884418713223833_9145589430013662246\":{\"v\":\"1676046825000\",\"opk\":\"java.math.BigInteger:{mot:9062352550013045460;mas:1;content:9165894402213590928}\"},\"9144543752013303034\":{\"v\":{\"c\":\"ref\",\"objectTypeId\":\"9144593476213342411\",\"v\":\"java.math.BigInteger:{mot:9144593476213342411;mas:1;content:9149095228413393646}\",\"icon\":\"/solutions/tfnecu/ri/img/svg/phone_number.svg\",\"text\":\"979117583\",\"objectId\":\"9149095228413393646\",\"url\":\"/csrdesktop/csrdesktop.jsp#!other;customerId=9149095187413929612;contextId=1xmytrvv8qhry;sectionId=salesOrders;objectUrl=L25jb2JqZWN0LmpzcD9pZD05MTQ5MDk1MjI4NDEzMzkzNjQ2\"}},\"9072741107013063688\":{\"v\":{\"c\":\"ref\",\"objectTypeId\":\"9126083628313449001\",\"v\":\"java.math.BigInteger:{mot:9126083628313449001;mas:1;content:9165851195113762564}\",\"icon\":\"/skins/arctic/img/ico/types/svg/ico_default.svg\",\"text\":\"PREPAGO TODO EN UNO [979117583]\",\"objectId\":\"9165851195113762564\",\"url\":\"/csrdesktop/csrdesktop.jsp#!board;customerId=9149095187413929612;contextId=1xmytrvv8qhry;sectionId=salesOrders;objectId=9165851195113762564\"}}},\"selectable\":true,\"id\":\"java.math.BigInteger:{mot:9062352550013045461;mas:1;content:9165897642562981172}\"},\"java.math.BigInteger:{mot:9062352550013045461;mas:1;content:9165897642553931490}\":{\"data\":{\"9157884418713223833_9126090157513456523\":{\"v\":{\"c\":\"lst\",\"color\":null,\"v\":\"9129643639813420226\",\"obsolete\":null,\"text\":null},\"opk\":\"java.math.BigInteger:{mot:9062352550013045460;mas:1;content:9165894402113590559}\"},\"9157884418713223833_9145589430013662246\":{\"v\":\"1676046827000\",\"opk\":\"java.math.BigInteger:{mot:9062352550013045460;mas:1;content:9165894402113590559}\"},\"9144543752013303034\":{\"v\":{\"c\":\"ref\",\"objectTypeId\":\"9144593476213342411\",\"v\":\"java.math.BigInteger:{mot:9144593476213342411;mas:1;content:9149095238313052468}\",\"icon\":\"/solutions/tfnecu/ri/img/svg/phone_number.svg\",\"text\":\"987740316\",\"objectId\":\"9149095238313052468\",\"url\":\"/csrdesktop/csrdesktop.jsp#!other;customerId=9149095187413929612;contextId=1xmytrvv8qhry;sectionId=salesOrders;objectUrl=L25jb2JqZWN0LmpzcD9pZD05MTQ5MDk1MjM4MzEzMDUyNDY4\"}},\"9072741107013063688\":{\"v\":{\"c\":\"ref\",\"objectTypeId\":\"9126083628313449001\",\"v\":\"java.math.BigInteger:{mot:9126083628313449001;mas:1;content:9165851196313763709}\",\"icon\":\"/skins/arctic/img/ico/types/svg/ico_default.svg\",\"text\":\"PREPAGO TODO EN UNO [987740316]\",\"objectId\":\"9165851196313763709\",\"url\":\"/csrdesktop/csrdesktop.jsp#!board;customerId=9149095187413929612;contextId=1xmytrvv8qhry;sectionId=salesOrders;objectId=9165851196313763709\"}}},\"selectable\":true,\"id\":\"java.math.BigInteger:{mot:9062352550013045461;mas:1;content:9165897642553931490}\"},\"java.math.BigInteger:{mot:9062352550013045461;mas:1;content:9165854409157167953}\":{\"data\":{\"9157884418713223833_9126090157513456523\":{\"v\":{\"c\":\"lst\",\"color\":null,\"v\":\"9129643639813420226\",\"obsolete\":null,\"text\":null},\"opk\":\"java.math.BigInteger:{mot:9062352550013045460;mas:1;content:9165851165513732863}\"},\"9157884418713223833_9145589430013662246\":{\"v\":\"1675616215000\",\"opk\":\"java.math.BigInteger:{mot:9062352550013045460;mas:1;content:9165851165513732863}\"},\"9144543752013303034\":{\"v\":{\"c\":\"ref\",\"objectTypeId\":\"9144593476213342411\",\"v\":\"java.math.BigInteger:{mot:9144593476213342411;mas:1;content:9149095238313052468}\",\"icon\":\"/solutions/tfnecu/ri/img/svg/phone_number.svg\",\"text\":\"987740316\",\"objectId\":\"9149095238313052468\",\"url\":\"/csrdesktop/csrdesktop.jsp#!other;customerId=9149095187413929612;contextId=1xmytrvv8qhry;sectionId=salesOrders;objectUrl=L25jb2JqZWN0LmpzcD9pZD05MTQ5MDk1MjM4MzEzMDUyNDY4\"}},\"9072741107013063688\":{\"v\":{\"c\":\"ref\",\"objectTypeId\":\"9126083628313449001\",\"v\":\"java.math.BigInteger:{mot:9126083628313449001;mas:1;content:9165851196313763709}\",\"icon\":\"/skins/arctic/img/ico/types/svg/ico_default.svg\",\"text\":\"PREPAGO TODO EN UNO [987740316]\",\"objectId\":\"9165851196313763709\",\"url\":\"/csrdesktop/csrdesktop.jsp#!board;customerId=9149095187413929612;contextId=1xmytrvv8qhry;sectionId=salesOrders;objectId=9165851196313763709\"}}},\"selectable\":true,\"id\":\"java.math.BigInteger:{mot:9062352550013045461;mas:1;content:9165854409157167953}\"},\"java.math.BigInteger:{mot:9062352550013045461;mas:1;content:9165854661758479133}\":{\"data\":{\"9157884418713223833_9126090157513456523\":{\"v\":{\"c\":\"lst\",\"color\":null,\"v\":\"9129643639813420226\",\"obsolete\":null,\"text\":null},\"opk\":\"java.math.BigInteger:{mot:9062352550013045460;mas:1;content:9165851416513936352}\"},\"9157884418713223833_9145589430013662246\":{\"v\":\"1675617018000\",\"opk\":\"java.math.BigInteger:{mot:9062352550013045460;mas:1;content:9165851416513936352}\"},\"9144543752013303034\":{\"v\":{\"c\":\"ref\",\"objectTypeId\":\"9144593476213342411\",\"v\":\"java.math.BigInteger:{mot:9144593476213342411;mas:1;content:9149
"c\":\"com.netcracker.platform.ui.plugins.gwt.tablectrl.shared.transport.Column\",\"AVLoaded\":false,\"dataType\":\"DATE\",\"multiple\":false,\"readOnly\":false,\"minWidth\":0,\"serviceName\":null,\"hideName\":false,\"loadOnDemand\":false,\"symbolsCount\":0,\"name\":\"Fecha de envío\",\"width\":null,\"actionId\":null,\"showInFullscreenOnly\":false,\"filterType\":\"RANGE\",\"suppressAllDefaultValidators\":false},{\"isFilterable\":true,\"objectTypeId\":\"9062352550013045461\",\"presenterConfig\":{\"validatorConfigs\":[],\"createButtonActionId\":null,\"c\":\"com.netcracker.platform.ui.plugins.gwt.common.shared.transport.presenter.ReferencePresenterConfig\",\"lazyLoadService\":null,\"hideObjectTypeName\":false,\"loadReferenceListActionId\":null,\"explorerPopupWidgetContainerId\":null,\"plainReferenceList\":false,\"presenterClass\":null,\"associatedAttributeId\":null,\"popupCreator\":null,\"createPopupDsName\":null,\"showAddButton\":true,\"explorerPopupDsName\":null,\"showSearchPopupButton\":false,\"referenceListValues\":null,\"hideObjectTypeIcon\":true,\"explorerPopupActionId\":null,\"plainText\":false,\"refselConfig\":{\"externalCssFiles\":[\"/platform/ui/components/referenceselector/styles/refsel.css?cache=1735209827023\",\"/thirdparty/org.webjars.bower/perfect-scrollbar/0.6.11/perfect-scrollbar.min.css\"],\"c\":\"com.netcracker.platform.ui.plugins.gwt.common.shared.transport.reference.ReferenceSelectorResponse\",\"jsPArt\":\"new NCReferenceSelector(\\\"id_refsel1760473111\\\",[{\\\"label\\\":\\\"Explorar\\\",\\\"action\\\":\\\"com.netcracker.platform.ui.components.referenceselector.impl.object.NCObjectExplorerHelper\\\",\\\"tooltip\\\":\\\"Navegue en el explorador de referencia\\\",\\\"iconURL\\\":\\\"\\\\/platform\\\\/ui\\\\/components\\\\/referenceselector\\\\/img\\\\/svg\\\\/explore.svg\\\",\\\"actionType\\\":\\\"POPUP\\\"}])\\n\",\"id\":\"id_refsel1760473111\",\"htmlPart\":\"<div id=\\\"id_refsel1760473111_div\\\" class=\\\"refsel\\\">\\n<input type=\\\"hidden\\\" name=\\\"refsel1760473111\\\" id=\\\"id_refsel1760473111\\\" class=\\\"refsel_value\\\" value=\\\"\\\" title=\\\"{&quot;jsPlugins&quot;:[&quot;com.netcracker.platform.ui.components.referenceselector.impl.DefaultLocalizationHelper&quot;],&quot;ajaxURL&quot;:&quot;\\\\/platform\\\\/ui\\\\/components\\\\/referenceselector\\\\/controller.jsp&quot;,&quot;interactiveSearchDelay&quot;:&quot;200&quot;,&quot;autocompleteEnable&quot;:true,&quot;wrappableLabel&quot;:&quot;&quot;,&quot;PADDINGS_AND_BORDERS_PX&quot;:44,&quot;MIN_WIDTH_PX&quot;:80,&quot;UPPER_MIN_WIDTH_PX&quot;:200,&quot;actionControllerURL&quot;:&quot;\\\\/platform\\\\/ui\\\\/components\\\\/referenceselector\\\\/action_controller.jsp&quot;,&quot;initialValue&quot;:null}\\\"/><input type=\\\"hidden\\\" class=\\\"refsel_props\\\" value=\\\"{&quot;attrId&quot;:&quot;9144543752013303034&quot;,&quot;objectId&quot;:&quot;9149095187413929612&quot;,&quot;isReadOnly&quot;:false,&quot;isMultiple&quot;:false,&quot;searchFactory&quot;:&quot;9131838813913083651&quot;,&quot;session&quot;:&quot;1735657726997_1027497&quot;,&quot;objectTypeId&quot;:&quot;2091641841013994133&quot;,&quot;parentId&quot;:&quot;9134256259513156680&quot;,&quot;projectId&quot;:&quot;9134256259513156679&quot;,&quot;interactiveSearch&quot;:&quot;on&quot;,&quot;disableExplorer&quot;:false,&quot;reParams&quot;:{},&quot;referenceTypeIds&quot;:[&quot;9144593476213342411&quot;],&quot;referenceProjectId&quot;:&quot;9134256259513156679&quot;}\\\"/><div class=\\\"refsel_single\\\">\\n<div class=\\\"refsel_font_test\\\"></div>\\n<label class=\\\"refsel_input_label\\\"><img class=\\\"refsel_icon\\\" src=\\\"/platform/ui/components/referenceselector/img/svg/search.svg\\\" alt=\\\"\\\"/></label><input type=\\\"text\\\" id=\\\"id_refsel1760473111_input\\\" class=\\\"refsel_input\\\" size=\\\"30\\\" aria-label=\\\"Selector de referencias. Use las teclas de flechas de subida y bajada para navegar dentro de las entradas de la lista. Presione Ctrl+Alt+1 a Explorar\\\"/><a target=\\\"_blank\\\" class=\\\"refsel_link\\\" title=\\\"\\\"></a><i class=\\\"refsel_arrow\\\"></i></div>\\n</div>\\n\",\"externalJavaScriptFiles\":[\"/thirdparty/jrburke/requirejs/2.1.16/require.min.js\",\"/platform/ui/components/referenceselector/scripts/refsel_lib.js?cache=1735209827022\",\"/platform/ui/components/referenceselector/scripts/refsel.js?cache=1735209827023\"]},\"suppressAllDefaultValidators\":false,\"createPopupWidgetContainerId\":null},\"hidden\":false,\"shortWithTooltip\":false,\"def\":null,\"isSortable\":true,\"availableValues\":null,\"styleName\":null,\"loadingState\":\"ON_DEMAND\",\"required\":false,\"colspan\":0,\"redirectParams\":{},\"path\":[{\"attrId\":\"9144543752013303034\",\"c\":\"com.netcracker.platform.ui.plugins.gwt.common.shared.transport.PathElement\",\"objectTypeIds\":[\"9062352550013045461\"]}],\"ruleConfigs\":[],\"bind\":false,\"dynamicSecurity\":false,\"rowspan\":0,\"disabled\":false,\"id\":\"9144543752013303034\",\"maxWidth\":-1,\"c\":\"com.netcracker.platform.ui.plugins.gwt.tablectrl.shared.transport.Column\",\"AVLoaded\":false,\"dataType\":\"REFERENCE\",\"multiple\":false,\"readOnly\":true,\"minWidth\":0,\"serviceName\":null,\"hideName\":false,\"loadOnDemand\":false,\"symbolsCount\":0,\"name\":\"Número de Teléfono Móvil\",\"width\":null,\"actionId\":null,\"showInFullscreenOnly\":false,\"filterType\":\"EQUALS\",\"suppressAllDefaultValidators\":false},{\"isFilterable\":true,\"objectTypeId\":\"9062352550013045461\",\"presenterConfig\":{\"referenceList\":false,\"validatorConfigs\":[],\"c\":\"com.netcracker.platform.ui.plugins.gwt.common.shared.transport.presenter.ListBoxPresenterConfig\",\"lazyLoadService\":null,\"list_sort_mode\":null,\"multipleChoiseOption\":false,\"presenterClass\":null,\"checkboxSelectedListValue\":null,\"defaultToFirstOption\":false,\"listValues\":[{\"c\":\"lst\",\"color\":null,\"v\":\"9126090157513456546\",\"obsolete\":false,\"text\":\"Entrando\"},{\"c\":\"lst\",\"color\":null,\"v\":\"9129356568113011692\",\"obsolete\":false,\"text\":\"Negociando\"},{\"c\":\"lst\",\"color\":null,\"v\":\"9132986990213882980\",\"obsolete\":false,\"text\":\"Enviando\"},{\"c\":\"lst\",\"color\":null,\"v\":\"9126090157513456549\",\"obsolete\":false,\"text\":\"Procesando\"},{\"c\":\"lst\",\"color\":null,\"v\":\"9129643639813420226\",\"obsolete\":false,\"text\":\"Procesado\"},{\"c\":\"lst\",\"color\":null,\"v\":\"9132986990213882981\",\"obsolete\":false,\"text\":\"Error\"},{\"c\":\"lst\",\"color\":null,\"v\":\"
"}])\\n\",\"id\":\"id_refsel1773553810\",\"htmlPart\":\"<div id=\\\"id_refsel1773553810_div\\\" class=\\\"refsel\\\">\\n<input type=\\\"hidden\\\" name=\\\"refsel1773553810\\\" id=\\\"id_refsel1773553810\\\" class=\\\"refsel_value\\\" value=\\\"\\\" title=\\\"{&quot;jsPlugins&quot;:[&quot;com.netcracker.platform.ui.components.referenceselector.impl.DefaultLocalizationHelper&quot;],&quot;ajaxURL&quot;:&quot;\\\\/platform\\\\/ui\\\\/components\\\\/referenceselector\\\\/controller.jsp&quot;,&quot;interactiveSearchDelay&quot;:&quot;200&quot;,&quot;autocompleteEnable&quot;:true,&quot;wrappableLabel&quot;:&quot;&quot;,&quot;PADDINGS_AND_BORDERS_PX&quot;:44,&quot;MIN_WIDTH_PX&quot;:80,&quot;UPPER_MIN_WIDTH_PX&quot;:200,&quot;actionControllerURL&quot;:&quot;\\\\/platform\\\\/ui\\\\/components\\\\/referenceselector\\\\/action_controller.jsp&quot;,&quot;initialValue&quot;:null}\\\"/><input type=\\\"hidden\\\" class=\\\"refsel_props\\\" value=\\\"{&quot;attrId&quot;:&quot;9072741107013063688&quot;,&quot;objectId&quot;:&quot;9149095187413929612&quot;,&quot;isReadOnly&quot;:false,&quot;isMultiple&quot;:false,&quot;searchFactory&quot;:&quot;9131757268413855835&quot;,&quot;session&quot;:&quot;1735657727005_1027499&quot;,&quot;objectTypeId&quot;:&quot;2091641841013994133&quot;,&quot;parentId&quot;:&quot;9134256259513156680&quot;,&quot;projectId&quot;:&quot;9134256259513156679&quot;,&quot;interactiveSearch&quot;:&quot;on&quot;,&quot;disableExplorer&quot;:false,&quot;reParams&quot;:{},&quot;referenceTypeIds&quot;:[&quot;9126083628313449001&quot;],&quot;referenceProjectId&quot;:&quot;9134256259513156679&quot;}\\\"/><div class=\\\"refsel_single\\\">\\n<div class=\\\"refsel_font_test\\\"></div>\\n<label class=\\\"refsel_input_label\\\"><img class=\\\"refsel_icon\\\" src=\\\"/platform/ui/components/referenceselector/img/svg/search.svg\\\" alt=\\\"\\\"/></label><input type=\\\"text\\\" id=\\\"id_refsel1773553810_input\\\" class=\\\"refsel_input\\\" size=\\\"30\\\" aria-label=\\\"Selector de referencias. Use las teclas de flechas de subida y bajada para navegar dentro de las entradas de la lista. Presione Ctrl+Alt+1 a Explorar\\\"/><a target=\\\"_blank\\\" class=\\\"refsel_link\\\" title=\\\"\\\"></a><i class=\\\"refsel_arrow\\\"></i></div>\\n</div>\\n\",\"externalJavaScriptFiles\":[\"/thirdparty/jrburke/requirejs/2.1.16/require.min.js\",\"/platform/ui/components/referenceselector/scripts/refsel_lib.js?cache=1735209827022\",\"/platform/ui/components/referenceselector/scripts/refsel.js?cache=1735209827023\"]},\"suppressAllDefaultValidators\":false,\"createPopupWidgetContainerId\":null},\"hidden\":false,\"shortWithTooltip\":false,\"def\":null,\"isSortable\":true,\"availableValues\":null,\"styleName\":null,\"loadingState\":\"ON_DEMAND\",\"required\":false,\"colspan\":0,\"redirectParams\":{},\"path\":[{\"attrId\":\"9072741107013063688\",\"c\":\"com.netcracker.platform.ui.plugins.gwt.common.shared.transport.PathElement\",\"objectTypeIds\":[\"9062352550013045461\"]}],\"ruleConfigs\":[],\"bind\":false,\"dynamicSecurity\":false,\"rowspan\":0,\"disabled\":false,\"id\":\"9072741107013063688\",\"maxWidth\":-1,\"c\":\"com.netcracker.platform.ui.plugins.gwt.tablectrl.shared.transport.Column\",\"AVLoaded\":false,\"dataType\":\"REFERENCE\",\"multiple\":false,\"readOnly\":true,\"minWidth\":0,\"serviceName\":null,\"hideName\":false,\"loadOnDemand\":false,\"symbolsCount\":0,\"name\":\"Referencia a BPI\",\"width\":null,\"actionId\":null,\"showInFullscreenOnly\":false,\"filterType\":\"EQUALS\",\"suppressAllDefaultValidators\":false}],\"pagingDescriptor\":{\"fullscreenCount\":50,\"c\":\"com.netcracker.platform.ui.plugins.gwt.tablectrl.shared.transport.RequestPagingDescriptor\",\"count\":10,\"from\":0},\"pageSize\":0,\"userViewHeaderEnabled\":\"true\",\"styleName\":\"widgetContainerId_9157884230013223760\",\"services\":[{\"c\":\"com.netcracker.platform.ui.plugins.gwt.common.shared.transport.lazyload.ServiceDescriptor\",\"name\":\"platformService\",\"serviceClassName\":\"com.netcracker.jsp.dashboard.widgets.rest.service.lazyload.PlatformDataLoadService\"}],\"title\":\"Cambiar Historial\",\"declarativeRules\":[],\"actionIds\":[\"9157884230013223760_9147845456013927818\",\"9157884230013223760_9147845456013927790\",\"9157884230013223760_9135248797013752720\"],\"actionConfigs\":[{\"onAfterCallAction\":null,\"c\":\"com.netcracker.platform.ui.plugins.gwt.core.shared.config.ActionConfig\",\"additionalParams\":{\"localizedName\":\"9147845572113927830\",\"style\":\"TableCtrl-button-icon CollapseChanges\",\"title\":\"Contraer todos los cambios\"},\"actionClass\":\"com.netcracker.solutions.tfnecu.gwtlinkage.client.actions.ExpandCollapseChangesAction\",\"onCallAction\":null,\"hotkey\":null,\"securitySensitive\":false,\"id\":\"9157884230013223760_9147845456013927818\",\"onBeforeCallAction\":null},{\"onAfterCallAction\":null,\"c\":\"com.netcracker.platform.ui.plugins.gwt.core.shared.config.ActionConfig\",\"additionalParams\":{\"expand\":\"true\",\"localizedName\":\"9147845546013927827\",\"style\":\"TableCtrl-button-icon ExpandChanges\",\"title\":\"Muestra todos los cambios\"},\"actionClass\":\"com.netcracker.solutions.tfnecu.gwtlinkage.client.actions.ExpandCollapseChangesAction\",\"onCallAction\":null,\"hotkey\":null,\"securitySensitive\":false,\"id\":\"9157884230013223760_9147845456013927790\",\"onBeforeCallAction\":null},{\"onAfterCallAction\":null,\"c\":\"com.netcracker.platform.ui.plugins.gwt.core.shared.config.ActionConfig\",\"additionalParams\":{},\"actionClass\":\"com.netcracker.uiplugins.gwt.common.client.action.impl.NOOPAction\",\"onCallAction\":null,\"hotkey\":null,\"securitySensitive\":false,\"id\":\"9157884230013223760_9135248797013752720\",\"onBeforeCallAction\":null}],\"lazyLoadUrl\":\"/rest/WidgetsOOB/lazy/parameters\",\"tccrSorting\":{\"c\":\"com.netcracker.platform.ui.plugins.gwt.tablectrl.shared.transport.SortingDescriptor\",\"sortings\":{\"9157884418713223833_9145589430013662246\":{\"c\":\"com.netcracker.platform.ui.plugins.gwt.tablectrl.shared.transport.SortingDescriptorItem\"}}},\"customizeViewConfigResponse\":{\"c\":\"com.netcracker.platform.ui.plugins.gwt.tablectrl.shared.transport.userviews.configmodification.TableCustomizeViewConfigResponse\",\"dsName\":\"TableCustomizeViewDS\",\"columnModificationInfoMapping\":{\"c\":\"com.netcracker.platform.ui.plugins.gwt.tablectrl.shared.transport.userviews.configmodification.ColumnModificationInfoMapping\",\"columnModifications\":[{\"path\":\"9062352550013045460:9145589430013662246\",\"c\":\"com.netcracker.platform.ui.plugins.gwt.tablectrl.shared.transport.userviews.configmodification.AttributeColumnModification\",\"viewInFullScreenOnly\":false,\"removed\":false,\"preConfigured\":true,\"id\":\"9157884418713223833\"},{\"path\":\"\",\"c\":\"com.netcracker.platform.ui.plugins.gwt.tablectrl.shared.transport.userviews.configmodification.AttributeColumnModification\",\"viewInFullScreenOnly\":false,\"removed\":false,\"preConfigured\":true,\"id\":\"9144543752013303034\"},{\"path\":\"\",\"c\":\"com.netcracker.platform.ui.plugins.gwt.tablectrl.shared.transport.userviews.configmodification.AttributeColumnModification\",\"viewInFullScreenOnly\":false,\"removed\":false,\"preConfigured\":true,\"id\":\"9157787402013182976\"},{\"path\":\"9062352550013045460:9126090157513456523\",\"c\":\"com.netcracker.platform.ui.plugins.gwt.tablectrl.shared.transport.userviews.configmodification.AttributeColumnModification\",\"viewInFullScreenOnly\":false,\"removed\":false,\"preConfigured\":true,\"id\":\"9157884418713223833\"},{\"path\":\"\",\"c\":\"com.netcracker.platform.ui.plugins.gwt.tablectrl.shared.transport.userviews.configmodification.AttributeColumnModification\",\"viewInFullScreenOnly\":false,\"removed\":false,\"preConfigured\":true,\"id\":\"9157884418713223833\"},{\"path\":\"\",\"c\":\"com.netcracker.platform.ui.plugins.gwt.tablectrl.shared.transport.userviews.configmodification.AttributeColumnModification\",\"viewInFullScreenOnly\":false,\"removed\":false,\"preConfigured\":true,\"id\":\"9072741107013063688\"}],\"columnModificationInfos\":[{\"c\":\"com.netcracker.platform.ui.plugins.gwt.tablectrl.shared.transport.userviews.configmodification.ColumnModificationInfo\",\"name\":\"Fecha de envío\"},{\"c\":\"com.netcracker.platform.ui.plugins.gwt.tablectrl.shared.transport.userviews.configmodification.ColumnModificationInfo\",\"name\":\"Número de Teléfono Móvil\"},{\"c\":\"com.netcracker.platform.ui.plugins.gwt.tablectrl.shared.transport.userviews.configmodification.ColumnModificationInfo\",\"name\":\"Cambios\"},{\"c\":\"com.netcracker.platform.ui.plugins.gwt.tablectrl.shared.transport.userviews.configmodification.ColumnModificationInfo\",\"name\":\"Estado\"},{\"c\":\"com.netcracker.platform.ui.plugins.gwt.tablectrl.shared.transport.userviews.configmodification.ColumnModificationInfo\",\"name\":\"Orden de venta\"},{\"c\":\"com.netcracker.platform.ui.plugins.gwt.tablectrl.shared.transport.userviews.configmodification.ColumnModificationInfo\",\"name\":\"Referencia a BPI\"}]},\"targetOTs\":[\"9062352550013045461\"]},\"lazyLoadMode\":\"MERGED\",\"tableCtrlConfigDescriptor\":{\"c\":\"com.netcracker.platform.ui.plugins.gwt.tablectrl.shared.transport.TableCtrlConfigDescriptor\",\"columnModifications\":[]},\"toolbars\":[{\"toolbarItemConfigs\":[{\"styleDisabled\":null,\"c\":\"com.netcracker.platform.ui.plugins.gwt.common.shared.transport.ButtonConfig\",\"tooltip\":null,\"icon\":null,\"actionIds\":null,\"buttonType\":\"BUTTON\",\"actionId\":\"9157884230013223760_9147845456013927790\",\"additionalParameters\":{\"localizedName1\":\"localizedName1\",\"expand\":\"true\",\"expand0\":\"expand0\"},\"style\":\"TableCtrl-button-icon ExpandChanges\",\"popupDirection\":\"true\",\"id\":\"9147845456013927790\",\"text\":\"Muestra todos los cambios\",\"objectTypes\":null},{\"styleDisabled\":null,\"c\":\"com.netcracker.platform.ui.plugins.gwt.common.shared.transport.ButtonConfig\",\"tooltip\":null,\"icon\":null,\"actionIds\":null,\"buttonType\":\"BUTTON\",\"actionId\":\"9157884230013223760_9147845456013927818\",\"additionalParameters\":{\"localizedName0\":\"localizedName0\"},\"style\":\"TableCtrl-button-icon CollapseChanges\",\"popupDirection\":\"true\",\"id\":\"9147845456013927818\",\"text\":\"Contraer todos los cambios\",\"objectTypes\":null}],\"c\":\"com.netcracker.platform.ui.plugins.gwt.common.shared.transport.Toolbar\",\"visible\":true,\"style\":\"nc-toolbar-top\",\"position\":\"TOP\",\"align\":\"LEFT\"}],\"freezeErrorMessages\":false},\"status\":\"SUCCESS\"}"
        }
    ]
}

# %%
from datetime import datetime
for key, value in json.loads(response['responses'][0]['body'])['data'].items():
    date_ts = int(value['data']['9157884418713223833_9145589430013662246']['v']) / 1000
    date = datetime.fromtimestamp(date_ts).strftime('%Y-%m-%d %H:%M:%S')
    message = value['data']['9072741107013063688']['v']['text']
    print(date, message)

# %% [markdown]
# ### FACTURACIÓN

# %%
# SECCION FACTURACION 

url = "https://fullstack.movistar.com.ec/rest/UIPlugins/WidgetRequestProcessor/process"

payload = 'request=%7B%22requests%22%3A%5B%7B%22path%22%3A%22%2Frest%2FUIPlugins%2
escriptor%5C%22%3A%7B%5C%22c%5C%22%3A%5C%22com.netcracker.platform.ui.plugins.gwt.tablectrl.shared.transport.RequestPagingDescriptor%5C%22%2C%5C%22from%5C%22%3A0%2C%5C%22count%5C%22%3A10%2C%5C%22fullscreenCount%5C%22%3A0%7D%2C%5C%22filteringDescriptor%5C%22%3A%7B%5C%22c%5C%22%3A%5C%22com.netcracker.platform.ui.plugins.gwt.tablectrl.shared.transport.filtering.FilteringDescriptor%5C%22%2C%5C%22filters%5C%22%3A%7B%7D%7D%2C%5C%22c%5C%22%3A%5C%22com.netcracker.platform.ui.plugins.rest.service.transport.request.TableCtrlRequest%5C%22%7D%22%2C%22c%22%3A%22com.netcracker.platform.ui.plugins.gwt.common.shared.transport.widget.request.WidgetTransportRequest%22%7D%5D%2C%22groupTimeout%22%3A%22100000%22%2C%22c%22%3A%22com.netcracker.platform.ui.plugins.gwt.common.shared.transport.widget.request.WidgetTransportGroupRequest%22%7D'

p_f = decode_payload(payload)

objectId = '9149095182513799619'
contextId = '1xkvf3qn6bv7r'
customerId = '9149095182513799619'
biling_account_id = '9149095236013542262'

d = str(p_f['requests'][0]['body']['objectPKs'])
d2 = re.sub(r'content:\d+', f'content:{objectId}', d)
p_f['requests'][0]['body']['objectPKs'] = eval(d2)
p_f['requests'][0]['body']['requestParams']['objectId'] = objectId
p_f['requests'][0]['body']['requestParams']['initializationParams']['ncObjectID'] = objectId
p_f['requests'][0]['body']['requestParams']['initializationParams']['csrdContext']['ctx_csrd_page_params']['customerId'] = customerId
p_f['requests'][0]['body']['requestParams']['initializationParams']['csrdContext']['ctx_cihm_customer_id'] = customerId
p_f['requests'][0]['body']['requestParams']['initializationParams']['csrdContext']['ctx_csrd_filter_context_id'] = contextId
p_f['requests'][0]['body']['requestParams']['initializationParams']['csrdContext']['ctx_cihm_billing_account_id'] = biling_account_id
d = str(p_f['requests'][0]['body']['requestParams']['initializationParams']['objectPK'])
d2 = re.sub(r'content:\d+', f'content:{objectId}', d)
p_f['requests'][0]['body']['requestParams']['initializationParams']['objectPK'] = d2

payload = encode_payload(p_f)

headers = {
  'Cookie': 'JSESSIONID=x464LxDduFNjDhIBAlh4DFDfvTc5vWvLWZunlLpVThCaXAr_9sec!-55552224; MRHSession=3fed8122215cde519fa16d346625ef74; F5_ST=1z1z1z1738256795z36000; TIN=300000; LastMRH_Session=6625ef74; LastMRH_Session=6625ef74; MRHSession=3fed8122215cde519fa16d346625ef74; nc.esc.tid=gxxft2qf5xf0',
  'cfadmin': 'U1zD-eXhp-ioqO-Vfc7-rMFi-Njza'
}

response = requests.request("POST", url, headers=headers, data=payload)

r = response.json()

# %%
jv = json.loads(r['responses'][0]['body'])
results = []
pattern = r'java\.math\.BigInteger:\{mot:\d+;mas:\d+;content:\d+\}'

# Encontrar todas las claves que coinciden con el patrón
matching_keys = [key for key in jv['data'].keys() if re.match(pattern, key)]

status_dict = {
    '9135405314613494989': 'OK Activo',
    '9135405314613494990': 'PE Pendiente',
    '9135405314613494991': 'SU Suspendido',
    '9135405314613494992': 'TA Esperando por Terminación',
    '9135405314613494993': 'TX Terminado'
    }

def get_status_text(Estado):
    return status_dict.get(Estado, 'Estado no encontrado')

for idx, key in enumerate(matching_keys):
    Cuenta_line = jv['data'][key]['data']['-1']['v']['text']
    Estado = jv['data'][key]['data']['9135385564913486875']['v']['v']
    forma_pago = jv['data'][key]['data']['9135699425113324669']['v']['text']
    Ultima_c_factura = jv['data'][key]['data']['9135386130713487750']['v']
    try:
        Ultima_f_factura = int(jv['data'][key]['data']['9134741282113214046']['v'])
        dt = datetime.fromtimestamp(Ultima_f_factura / 1000).strftime('%Y-%m-%d')
    except (KeyError, ValueError, TypeError):
        Ultima_f_factura = 'No contiene fecha'
        dt = 'No disponible'
    
    results.append({
        'Cuenta_line': Cuenta_line,
        'Estado': get_status_text(Estado),
        'forma_pago': forma_pago,
        'Ultima_c_factura': Ultima_c_factura,
        'Ultima_f_factura':dt
    })
    df_fac = pd.DataFrame(results)

df_fac
# Out:
#          Cuenta_line        Estado forma_pago Ultima_c_factura  \
# 0  Prepago: 41612559     OK Activo   Efectivo                0
# 1  Pospago: 41584659  TX Terminado   Efectivo                0
# 2  Pospago: 49447770     OK Activo   Efectivo             0.99
# 3  Prepago: 42355363     OK Activo   Efectivo                0
# 4  Prepago: 25928442     OK Activo   Efectivo                0
# 5  Pospago: 45711041     OK Activo   Efectivo            22.76
#
#   Ultima_f_factura
# 0    No disponible
# 1       2023-07-28
# 2       2024-10-08
# 3    No disponible
# 4       2017-09-25
# 5       2024-01-08

# %% [markdown]
# ### DIRECCION

# %%
# SECCION DIRECCION

url = "https://fullstack.movistar.com.ec/rest/UIPlugins/WidgetRequestProcessor/process"

payload = 'request=%7B%22requests%22%3A%5B%7B%22path%22%3A%22%2Frest%2FUIPlugins%2FCtrl%2Frefresh%22%2C%22body%22%3A%22%7B%5C%22dsName%5C%22%3A%5C%22TfnLocationsPlatformTableCtrlDS%5C%22%2C%5C%22objectPKs%5C%22%3A%5B%5C%22java.math.BigInteger%3A%7Bmot%3A2091641841013994133%3Bmas%3A1%3Bcontent%3A9149095206313263681%7D%5C%22%5D%2C%5C%22requestParams%5C%22%3A%7B%5C%22checkBoxEnabled%5C%22%3A%5C%22true%5C%22%2C%5C%22customizationEnabled%5C%22%3A%5C%22false%5C%22%2C%5C%22mask_field_resized%5C%22%3A%5C%22true%5C%22%2C%5C%22modal_grid_panel%5C%22%3A%5C%22true%5C%22%2C%5C%22mergedWidgetContainerId%5C%22%3Anull%2C%5C%22gwtClass%5C%22%3A%5C%22com.netcracker.platform.ui.plugins.gwt.tablectrl.client.TableCtrl%5C%22%2C%5C%22coreDsId%5C%22%3A%5C%229134660771413142816%5C%22%2C%5C%22pageSize%5C%22%3A%5C%2210%5C%22%2C%5C%22ncAttributes%5C%22%3A%5C%22-1%2C9132251685613889259%2C-2%5C%22%2C%5C%22userViewHeaderEnabled%5C%22%3A%5C%22true%5C%22%2C%5C%22title%5C%22%3A%5C%22Ubicaciones%20del%20cliente%5C%22%2C%5C%22pagingEnabled%5C%22%3A%5C%22true%5C%22%2C%5C%22customizationColumnNumberEnabled%5C%22%3A%5C%22true%5C%22%2C%5C%22objectId%5C%22%3A%5C%229149095206313263681%5C%22%2C%5C%22dashboardID%5C%22%3A%5C%229144932611213850040%5C%22%2C%5C%22widgetId%5C%22%3A%5C%229144942818913865505%5C%22%2C%5C%22drawFakeCheckboxes%5C%22%3A%5C%22false%5C%22%2C%5C%22initializationParams%5C%22%3A%7B%5C%22customizeReferenceFields%5C%22%3A%5C%22true%5C%22%2C%5C%22dashboardID%5C%22%3A%5C%229144932611213850040%5C%22%2C%5C%22referenceCustomizer%5C%22%3A%5C%22boardReferenceCustomizer%5C%22%2C%5C%22ncObjectID%5C%22%3A%5C%229149095206313263681%5C%22%2C%5C%22csrdContext%5C%22%3A%7B%5C%22ctx_csrd_section_id%5C%22%3A%5C%22locations%5C%22%2C%5C%22ctx_csrd_page_token%5C%22%3A%5C%22!board%5C%22%2C%5C%22ctx_csrd_page_params%5C%22%3A%7B%5C%22customerId%5C%22%3A%5C%229149095206313263681%5C%22%2C%5C%22sectionId%5C%22%3A%5C%22locations%5C%22%7D%2C%5C%22ctx_cihm_customer_id%5C%22%3A%5C%229149095206313263681%5C%22%2C%5C%22ctx_csrd_filter_context_id%5C%22%3A%5C%221xidnkixu7hv7%5C%22%2C%5C%22ctx_csrd_page_host%5C%22%3A%5C%22%2Fcsrdesktop%2Fcsrdesktop.jsp%5C%22%2C%5C%22ctx_cihm_billing_account_id%5C%22%3A%5C%229149095190513612851%5C%22%7D%2C%5C%22showOperationsButton%5C%22%3A%5C%22true%5C%22%2C%5C%22drawFakeCheckboxes%5C%22%3A%5C%22false%5C%22%2C%5C%22objectPK%5C%22%3A%5C%22java.math.BigInteger%3A%7Bmot%3A0%3Bmas%3A1%3Bcontent%3A9149095206313263681%7D%5C%22%7D%2C%5C%22pageContext%5C%22%3A%5B%7B%5C%22name%5C%22%3A%5C%22cfadmin%5C%22%2C%5C%22value%5C%22%3A%5C%22oUPw-Jz0J-TmJX-mDIl-bnxV-tNdA%5C%22%7D%5D%2C%5C%22widgetContainerId%5C%22%3A%5C%229144932720113850181%5C%22%2C%5C%22editable%5C%22%3Atrue%2C%5C%22hideEditableButton%5C%22%3Afalse%2C%5C%22urlParams%5C%22%3A%7B%7D%7D%2C%5C%22requestTimeout%5C%22%3A%7B%5C%22c%5C%22%3A%5C%22com.netcracker.platform.ui.plugins.gwt.model.shared.RequestTimeout%5C%22%2C%5C%22timeoutId%5C%22%3A%5C%22bx8RWT19gWA4D1sznyldjEp2oMxgmKYKAZqOTHDGIpilTuHSaJ_9144932720113850181%5C%22%2C%5C%22v%5C%22%3A%5C%2220000%5C%22%7D%2C%5C%22pagingDescriptor%5C%22%3A%7B%5C%22c%5C%22%3A%5C%22com.netcracker.platform.ui.plugins.gwt.tablectrl.shared.transport.RequestPagingDescriptor%5C%22%2C%5C%22from%5C%22%3A0%2C%5C%22count%5C%22%3A10%2C%5C%22fullscreenCount%5C%22%3A0%7D%2C%5C%22filteringDescriptor%5C%22%3A%7B%5C%22c%5C%22%3A%5C%22com.netcracker.platform.ui.plugins.gwt.tablectrl.shared.transport.filtering.FilteringDescriptor%5C%22%2C%5C%22filters%5C%22%3A%7B%7D%7D%2C%5C%22c%5C%22%3A%5C%22com.netcracker.platform.ui.plugins.rest.service.transport.request.TableCtrlRequest%5C%22%7D%22%2C%22c%22%3A%22com.netcracker.platform.ui.plugins.gwt.common.shared.transport.widget.request.WidgetTransportRequest%22%7D%5D%2C%22groupTimeout%22%3A%22100000%22%2C%22c%22%3A%22com.netcracker.platform.ui.plugins.gwt.common.shared.transport.widget.request.WidgetTransportGroupRequest%22%7D'
p1 = decode_payload(payload)

objectId = '9149095182513799619'
contextId = '1xkvf3qn6bv7r'
customerId = '9149095182513799619'
biling_account_id = '9149095236013542262'

d = str(p1['requests'][0]['body']['objectPKs'])
d2 = re.sub(r'content:\d+', f'content:{objectId}', d)
p1['requests'][0]['body']['objectPKs'] = eval(d2)
p1['requests'][0]['body']['requestParams']['objectId'] = objectId
p1['requests'][0]['body']['requestParams']['initializationParams']['ncObjectID'] = objectId
p1['requests'][0]['body']['requestParams']['initializationParams']['csrdContext']['ctx_csrd_page_params']['customerId'] = customerId
p1['requests'][0]['body']['requestParams']['initializationParams']['csrdContext']['ctx_cihm_customer_id'] = customerId
p1['requests'][0]['body']['requestParams']['initializationParams']['csrdContext']['ctx_csrd_filter_context_id'] = contextId
p1['requests'][0]['body']['requestParams']['initializationParams']['csrdContext']['ctx_cihm_billing_account_id'] = biling_account_id
d = str(p1['requests'][0]['body']['requestParams']['initializationParams']['objectPK'])
d2 = re.sub(r'content:\d+', f'content:{objectId}', d)
p1['requests'][0]['body']['requestParams']['initializationParams']['objectPK'] = d2

payload = encode_payload(p1)

headers = {
  'Cookie': 'JSESSIONID=x464LxDduFNjDhIBAlh4DFDfvTc5vWvLWZunlLpVThCaXAr_9sec!-55552224; MRHSession=3fed8122215cde519fa16d346625ef74; F5_ST=1z1z1z1738256795z36000; TIN=300000; LastMRH_Session=6625ef74; LastMRH_Session=6625ef74; MRHSession=3fed8122215cde519fa16d346625ef74; nc.esc.tid=gxxft2qf5xf0',
  'cfadmin': 'U1zD-eXhp-ioqO-Vfc7-rMFi-Njza'
}

response = requests.request("POST", url, headers=headers, data=payload)

# %%
r = response.json()
direccion = json.loads(r['responses'][0]['body'])
results = []

for key in direccion['data']:
    results.append({
        'Direccion': direccion['data'][key]['data']['9132251685613889259']['v']['text']
    })
    dir = pd.DataFrame(results)
dir
# Out:
#                                            Direccion
# 0   Republica y Pradera 500 , CUENCA, CUENCA, AZU...

# %% [markdown]
# ### Seccion Cuentas de Facturacion - BANCO - (Que su forma de pago no sea en Efectivo)

# %%
url = "https://fullstack.movistar.com.ec/rest/UIPlugins/WidgetRequestProcessor/process"

payload = 'request=%7B%22requests%22%3A%5B%7B%22path%22%3A%22%2Frest%2FUIPlugins%2FCtrl%2Frefresh%22%2C%22body%22%3A%22%7B%5C%22dsName%5C%22%3A%5C%22CbmBaipPaymentMandateTransportDS%5C%22%2C%5C%22objectPKs%5C%22%3A%5B%5C%22java.math.BigInteger%3A%7Bmot%3A9135688263813316188%3Bmas%3A1%3Bcontent%3A9161251211263891063%7D%5C%22%5D%2C%5C%22requestParams%5C%22%3A%7B%5C%22customizationEnabled%5C%22%3A%5C%22false%5C%22%2C%5C%
])
d2 = re.sub(r'content:\d+', f'content:{objectId}', d)
p['requests'][0]['body']['objectPKs'] = eval(d2)
p['requests'][0]['body']['requestParams']['objectId'] = objectId
p['requests'][0]['body']['requestParams']['initializationParams']['ncObjectID'] = objectId
p['requests'][0]['body']['requestParams']['initializationParams']['csrdContext']['ctx_cihm_line_id'] = line_id #nuevo de facturacion
p['requests'][0]['body']['requestParams']['initializationParams']['csrdContext']['ctx_csrd_page_params']['customerId'] = customerId
p['requests'][0]['body']['requestParams']['initializationParams']['csrdContext']['ctx_csrd_page_params']['contextId'] = contextId
p['requests'][0]['body']['requestParams']['initializationParams']['csrdContext']['ctx_csrd_page_params']['objectId'] = objectId
p['requests'][0]['body']['requestParams']['initializationParams']['csrdContext']['ctx_cihm_customer_id'] = customerId
p['requests'][0]['body']['requestParams']['initializationParams']['csrdContext']['ctx_csrd_filter_context_id'] = contextId
p['requests'][0]['body']['requestParams']['initializationParams']['csrdContext']['ctx_cihm_billing_account_id'] = biling_account_id
d = str(p['requests'][0]['body']['requestParams']['initializationParams']['objectPK'])
d2 = re.sub(r'content:\d+', f'content:{objectId}', d)

payload = encode_payload(p)

headers = {
  'Cookie': 'JSESSIONID=x464LxDduFNjDhIBAlh4DFDfvTc5vWvLWZunlLpVThCaXAr_9sec!-55552224; MRHSession=3fed8122215cde519fa16d346625ef74; F5_ST=1z1z1z1738256795z36000; TIN=300000; LastMRH_Session=6625ef74; LastMRH_Session=6625ef74; MRHSession=3fed8122215cde519fa16d346625ef74; nc.esc.tid=gxxft2qf5xf0',
  'cfadmin': 'U1zD-eXhp-ioqO-Vfc7-rMFi-Njza'
}

response = requests.request("POST", url, headers=headers, data=payload)

# %%
r_c_b = response.json()
r_data = json.loads(r_c_b['responses'][0]['body'])

results = []
for key in r_data['data']:
    results.append({
        'Mandato': r_data['data'][key]['data']['-1']['v']['text'],
        'Titular tarjeta': r_data['data'][key]['data']['9145434158113873086']['v'],
        'Cuenta': r_data['data'][key]['data']['9135688263813316208']['v']['text'],
        'Nombre de banco': r_data['data'][key]['data']['9136070420013600506']['v']['text']
    })
    df = pd.DataFrame(results)
df

# %% [markdown]
# ### Sección Cambiar Historial

# %%
"""
"csrdContext": {
    "ctx_csrd_section_id": "salesOrders",
    "ctx_csrd_page_token": "!board",
    "ctx_csrd_page_params": {
        "customerId": "9149095206113030409",
        "sectionId": "salesOrders"
    },
    "ctx_cihm_customer_id": "9149095206113030409",
    "ctx_csrd_filter_context_id": "1xidnl2ywfopi",
    "ctx_csrd_page_host": "/csrdesktop/csrdesktop.jsp",
    "ctx_cihm_billing_account_id": "9149095234113467094"
},

objectId: '9161282613113642273'

Actualiza en todos los lugares donde aparezca el ID de artículo o el ID del cliente anterior:
objectPKs[0] → coloca el nuevo ID del artículo en la sección content:.
requestParams.objectId → nuevo ID del artículo.
initializationParams.ncObjectID → nuevo ID del artículo.
ctx_csrd_page_params.objectId → nuevo ID del artículo.
ctx_csrd_page_params.customerId → nuevo ID de cliente (si cambias el cliente).
ctx_cihm_customer_id → nuevo ID de cliente.
ctx_cihm_billing_account_id → nuevo o correcto ID de cuenta de facturación para ese cliente.
ctx_csrd_filter_context_id → si tu aplicación requiere un ID de contexto de filtro único para una nueva sesión o nuevo cliente, también debes cambiarlo.

"""

# %% [markdown]
# ### Caracteristicas

# %%
url = "https://fullstack.movistar.com.ec/rest/UIPlugins/WidgetRequestProcessor/process"

payload = 'request=%7B%22requests%22%3A%5B%7B%22path%22%3A%22%2Frest%2FUIPlugins%2FCtrl%2Frefresh%22%2C%22body%22%3A%22%7B%5C%22dsName%5C%22%3A%5C%22LineItemCharacteristicsDS%5C%22%2C%5C%22objectPKs%5C%22%3A%5B%5C%22java.math.BigInteger%3A%7Bmot%3A9126083628313449001%3Bmas%3A1%3Bcontent%3A9161282613113642273%7D%5C%22%5D%2C%5C%22requestParams%5C%22%3A%7B%5C%22customizationEnabled%5C%22%3A%5C%22false%5C%22%2C%5C%22mask_field_resized%5C%22%3A%5C%22true%5C%22%2C%5C%22editable%5C%22%3Afalse%2C%5C%22modal_grid_panel%5C%22%3A%5C%22true%5C%22%2C%5C%22mergedWidgetContainerId%5C%22%3Anull%2C%5C%22gwtClass%5C%22%3A%5C%22com.netcracker.platform.ui.plugins.gwt.parctrl.client.ParCtrl%5C%22%2C%5C%22hideEditableButton%5C%22%3A%5C%22true%5C%22%2C%5C%22coreDsId%5C%22%3A%5C%229134229898013156551%5C%22%2C%5C%22userViewHeaderEnabled%5C%22%3A%5C%22true%5C%22%2C%5C%22title%5C%22%3A%5C%22+%5C%22%2C%5C%22requestGrouping%5C%22%3A%5C%22true%5C%22%2C%5C%22customizationColumnNumberEnabled%5C%22%3A%5C%22true%5C%22%2C%5C%22requestGrouping_name%5C%22%3A%5C%22characteristics%5C%22%2C%5C%22objectId%5C%22%3A%5C%229161282613113642273%5C%22%2C%5C%22dashboardID%5C%22%3A%5C%229147879890013954875%5C%22%2C%5C%22widgetId%5C%22%3A%5C%229147879469813954580%5C%22%2C%5C%22drawFakeCheckboxes%5C%22%3A%5C%22false%5C%22%2C%5C%22initializationParams%5C%22%3A%7B%5C%22customizeReferenceFields%5C%22%3A%5C%22true%5C%22%2C%5C%22referenceCustomizer%5C%22%3A%5C%22boardReferenceCustomizer%5C%22%2C%5C%22forceReloadTabData%5C%22%3Atrue%2C%5C%22ncObjectID%5C%22%3A%5C%229161282613113642273%5C%22%2C%5C%22csrdContext%5C%22%3A%7B%5C%22ctx_csrd_section_id%5C%22%3A%5C%22salesOrders%5C%22%2C%5C%22ctx_csrd_page_token%5C%22%3A%5C%22!board%5C%22%2C%5C%22ctx_csrd_page_params%5C%22%3A%7B%5C%22customerId%5C%22%3A%5C%229149095206113030409%5C%22%2C%5C%22sectionId%5C%22%3A%5C%22salesOrders%5C%22%2C%5C%22objectId%5C%22%3A%5C%229161282613113642273%5C%22%7D%2C%5C%22ctx_cihm_customer_id%5C%22%3A%5C%229149095206113030409%5C%22%2C%5C%22ctx_csrd_filter_context_id%5C%22%3A%5C%221xidnl2ywfopi%5C%22%2C%5C%22ctx_csrd_page_host%5C%22%3A%5C%22%2Fcsrdesktop%2Fcsrdesktop.jsp%5C%22%2C%5C%22ctx_cihm_billing_account_id%5C%22%3A%5C%229149095234113467094%5C%22%7D%2C%5C%22showOperationsButton%5C%22%3A%5C%22true%5C%22%2C%5C%22drawFakeCheckboxes%5C%22%3A%5C%22false%5C%22%2C%5C%22objectPK%5C%22%3A%5C%22java.math.BigInteger%3A%7Bmot%3A0%3Bmas%3A1%3Bcontent%3A9161282613113642273%7D%5C%22%7D%2C%5C%22pageContext%5C%22%3A%5B%7B%5C%22name%5C%22%3A%5C%22cfadmin%5C%22%2C%5C%22value%5C%22%3A%5C%22V18Q-v103-7VIE-ItBN-t5KL-Ho6J%5C%22%7D%5D%2C%5C%22widgetContainerId%5C%22%3A%5C%229147879890013954886%5C%22%2C%5C%22urlParams%5C%22%3A%7B%7D%7D%2C%5C%22requestTimeout%5C%22%3A%7B%5C%22c%5C%22%3A%5C%22com.netcracker.platform.ui.plugins.gwt.model.shared.RequestTimeout%5C%22%2C%5C%22timeoutId%5C%22%3A%5C%22GHNvDrzOkDQVM7XEGkYKQxOy2XafassyamFqcIzvhjBHEaGuKb_9147879890013954886%5C%22%2C%5C%22v%5C%22%3A%5C%2220000%5C%22%7D%7D%22%2C%22c%22%3A%22com.netcracker.platform.ui.plugins.gwt.common.shared.transport.widget.request.WidgetTransportRequest%22%7D%5D%2C%22groupTimeout%22%3A%22100000%22%2C%22c%22%3A%22com.netcracker.platform.ui.plugins.gwt.common.shared.transport.widget.request.WidgetTransportGroupRequest%22%7D'
objectId = '9149095830913546611'

payload_deco = decode_payload(payload)

d = str(payload_deco['requests'][0]['body']['objectPKs'])
d1 = re.sub(r'content:\d+', f'content:{objectId}', d)
payload_deco['requests'][0]['body']['objectPKs'] = d1
payload_deco['requests'][0]['body']['objectPKs'] = ast.literal_eval(payload_deco['requests'][0]['body']['objectPKs']) # quita comillas
payload_deco['requests'][0]['body']['requestParams']['objectId'] = objectId
payload_deco['requests'][0]['body']['requestParams']['initializationParams']['ncObjectID'] = objectId
payload_deco['requests'][0]['body']['requestParams']['initializationParams']['csrdContext']['ctx_csrd_page_params']['objectId'] = objectId
payload_deco['requests'][0]['body']['requestParams']['initializationParams']['csrdContext']['ctx_csrd_page_params']['customerId'] = '9149095186813124895'
payload_deco['requests'][0]['body']['requestParams']['initializationParams']['csrdContext']['ctx_cihm_customer_id']= '9149095186813124895'
payload_deco['requests'][0]['body']['requestParams']['initializationParams']['csrdContext']['ctx_cihm_billing_account_id']= '9149095182313539840'
payload_deco['requests'][0]['body']['requestParams']['initializationParams']['csrdContext']['ctx_csrd_filter_context_id'] = '1xidnsp4vsl83'
d = str(payload_deco['requests'][0]['body']['requestParams']['initializationParams']['objectPK'])
d2 = re.sub(r'content:\d+', f'content:{objectId}', d)
payload_deco['requests'][0]['body']['requestParams']['initializationParams']['objectPK'] = d2

payload = encode_payload(payload_deco)

headers = {
  'Cookie': 'bandwidth-info=eyJjb21wbGV0ZWQiOmZhbHNlLCJiYW5kd2lkdGhJbWFnZXMiOnt9fQ==; latency-info=eyJjb21wbGV0ZWQiOmZhbHNlfQ==; JSESSIONID=vVKyisqGiw8Pp0UdUnqwBnBLzxAUVO4Lti4ALG4oxWQpOX8sK_xY!-1100503567; TIN=284000; MRHSession=162929f9611d8f1a89de52dd224ae9ac; F5_ST=1z1z1z1738162052z36000; LastMRH_Session=224ae9ac; LastMRH_Session=224ae9ac; MRHSession=162929f9611d8f1a89de52dd224ae9ac; nc.esc.tid=r0xt1nlrdd0t',
  'cfadmin': 'V18Q-v103-7VIE-ItBN-t5KL-Ho6J',
}
response = requests.request("POST", url, headers=headers, data=payload)

# %%
r = response.json()
r = json.loads(r['responses'][0]['body'])

groups = r['config']['columns'][0]['groups']
results = []

for group in groups:
    try:
        bono_garantia = group['name']
        id_bono = group['fields'][2]['id']
        name_t = group['fields'][2]['name']
        data = r['data'] 
        target_key = None
        for key in data.keys():
            if 'java.math.BigInteger' in key:
                target_key = key
                break 
        if target_key:
            tarifa_bono = data[target_key]['data'][id_bono]['v']
            results.append({'Bono': bono_garantia, 'tarifa_bono': tarifa_bono, 'name_t': name_t})
        else:
            results.append({'Bono': bono_garantia, 'tarifa_bono': None, 'name_t': None})    
    except Exception as e:
        #results.append({'Bono': group['name'], 'tarifa_bono': None})
        continue

df = pd.DataFrame(results)
df_bono = df[df['name_t'] == 'Tarifa de bonificación de lealtad']

# %%
df_bono.reset_index(drop=True, inplace=True)
df_bono
# Out:
#                                        Bono tarifa_bono  \
# 0              BONO 5GB 3 MESES #1057786910        1.96
# 1            BONO B PERMANENCIA #0912457057       13.39
# 2  BONO 10GB PERMANENCIA $13.39 #0811645027       13.39
# 3            BONO D PERMANENCIA #0939107993       16.07
# 4            BONO C PERMANENCIA #0914028389       14.73
#
#                               name_t
# 0  Tarifa de bonificación de lealtad
# 1  Tarifa de bonificación de lealtad
# 2  Tarifa de bonificación de lealtad
# 3  Tarifa de bonificación de lealtad
# 4  Tarifa de bonificación de lealtad

# %% [markdown]
# ### Product Instances

# %%
url = "https://fullstack.movistar.com.ec/rest/UIPlugins/WidgetRequestProcessor/process"

payload = 'request=%7B%22requests%22%3A%5B%7B%22path%22%3A%22%2Frest%2FUIPlugins%2FCtrl%2Frefresh%22%2C%22body%22%3A%22%7B%5C%22dsName%5C%22%3A%5C%22TableCtrlDynamicFetchPlanDS%5C%22%2C%5C%22objectPKs%5C%22%3A%5B%5C%22java.math.BigInteger%3A%7Bmot%3A9126083628313449001%3Bmas%3A1%3Bcontent%3A9149095393613527061%7D%5C%22%5D%2C%5C%22requestParams%5C%22%3A%7B%5C%22checkBoxEnabled%5C%22%3A%5C%22false%5C%22%2C%5C%
5C%22%3A%7B%5C%22c%5C%22%3A%5C%22com.netcracker.platform.ui.plugins.gwt.model.shared.RequestTimeout%5C%22%2C%5C%22timeoutId%5C%22%3A%5C%22ODTTcD4z9B41JcFK5kYRnlzH3EtjBNp0P065eQ18RE6YZdOJVp_9148285126113024874%5C%22%2C%5C%22v%5C%22%3A%5C%2220000%5C%22%7D%2C%5C%22pagingDescriptor%5C%22%3A%7B%5C%22c%5C%22%3A%5C%22com.netcracker.platform.ui.plugins.gwt.tablectrl.shared.transport.RequestPagingDescriptor%5C%22%2C%5C%22from%5C%22%3A0%2C%5C%22count%5C%22%3A10%2C%5C%22fullscreenCount%5C%22%3A0%7D%2C%5C%22filteringDescriptor%5C%22%3A%7B%5C%22c%5C%22%3A%5C%22com.netcracker.platform.ui.plugins.gwt.tablectrl.shared.transport.filtering.FilteringDescriptor%5C%22%2C%5C%22filters%5C%22%3A%7B%7D%7D%2C%5C%22c%5C%22%3A%5C%22com.netcracker.platform.ui.plugins.rest.service.transport.request.TableCtrlRequest%5C%22%7D%22%2C%22c%22%3A%22com.netcracker.platform.ui.plugins.gwt.common.shared.transport.widget.request.WidgetTransportRequest%22%7D%5D%2C%22groupTimeout%22%3A%22100000%22%2C%22c%22%3A%22com.netcracker.platform.ui.plugins.gwt.common.shared.transport.widget.request.WidgetTransportGroupRequest%22%7D'
objectId = '9149095830913546611'
payload_deco = decode_payload(payload)

d = str(payload_deco['requests'][0]['body']['objectPKs'])
d1 = re.sub(r'content:\d+', f'content:{objectId}', d)
payload_deco['requests'][0]['body']['objectPKs'] = d1
payload_deco['requests'][0]['body']['objectPKs'] = ast.literal_eval(payload_deco['requests'][0]['body']['objectPKs']) # quita comillas
payload_deco['requests'][0]['body']['requestParams']['objectId'] = objectId
payload_deco['requests'][0]['body']['requestParams']['initializationParams']['ncObjectID'] = objectId
payload_deco['requests'][0]['body']['requestParams']['initializationParams']['csrdContext']['ctx_csrd_page_params']['objectId'] = objectId
payload_deco['requests'][0]['body']['requestParams']['initializationParams']['csrdContext']['ctx_csrd_page_params']['customerId'] = '9149095186813124895'
payload_deco['requests'][0]['body']['requestParams']['initializationParams']['csrdContext']['ctx_cihm_customer_id']= '9149095186813124895'
payload_deco['requests'][0]['body']['requestParams']['initializationParams']['csrdContext']['ctx_cihm_billing_account_id']= '9149095182313539840'
payload_deco['requests'][0]['body']['requestParams']['initializationParams']['csrdContext']['ctx_csrd_filter_context_id'] = '1xidnsp4vsl83'
d = str(payload_deco['requests'][0]['body']['requestParams']['initializationParams']['objectPK'])
d2 = re.sub(r'content:\d+', f'content:{objectId}', d)
payload_deco['requests'][0]['body']['requestParams']['initializationParams']['objectPK'] = d2

payload= encode_payload(payload_deco)

headers = {
  'Cookie': 'bandwidth-info=eyJjb21wbGV0ZWQiOmZhbHNlLCJiYW5kd2lkdGhJbWFnZXMiOnt9fQ==; latency-info=eyJjb21wbGV0ZWQiOmZhbHNlfQ==; JSESSIONID=vVKyisqGiw8Pp0UdUnqwBnBLzxAUVO4Lti4ALG4oxWQpOX8sK_xY!-1100503567; TIN=284000; MRHSession=162929f9611d8f1a89de52dd224ae9ac; F5_ST=1z1z1z1738162052z36000; LastMRH_Session=224ae9ac; LastMRH_Session=224ae9ac; MRHSession=162929f9611d8f1a89de52dd224ae9ac; nc.esc.tid=r0xt1nlrdd0t',
  'cfadmin': 'V18Q-v103-7VIE-ItBN-t5KL-Ho6J',
}
response = requests.request("POST", url, headers=headers, data=payload)

# %%
jv = response.json()
jv = json.loads(jv['responses'][0]['body'])
results = []
pattern = r'java\.math\.BigInteger:\{mot:\d+;mas:\d+;content:\d+\}'

matching_keys = [key for key in jv['data'].keys() if re.match(pattern, key)]

status_dict = {
        "9132857804713527190": "Activación en progreso",
        "9132857804713527191": "Activo",
        "9132857804713527192": "Suspension en progreso",
        "9132857804713527193": "Suspendido",
        "9132857804713527195": "Reanudación en progreso",
        "9132857804713527196": "Desconexión en progreso",
        "9132857804713527197": "Desconectado",
        "9132857804713527198": "Modificación en progreso",
        "9132857804713527199": "Cancelación de activación",
        "9132857804713527200": "Cancelación de desconexión",
        "9132857804713527201": "Cancelación de modificación",
        "9132857804713527202": "Cancelación de suspensión",
        "9132857804713527203": "Cancelación de la reanudación",
        "9134626543113464316": "Planeado",
        "9135241631713410866": "Activación pasada PONR",
        "9135241631713410879": "Modificación pasada PONR",
        "9135241631713410872": "Suspensión pasada PONR",
        "9135241631713410876": "Disconexión pasada PONR",
        "9135241631713410878": "Reanudación pasada PONR",
        "9135793174213637730": "Activación Cancelada",
        "9137949657313151303": "Completado",
        "9143940536813993067": "Expirado"
        }

def get_status_text(Estado):
    return status_dict.get(Estado, 'Estado no encontrado')

for idx, key in enumerate(matching_keys):
    Bono = jv['data'][key]['data']['-1']['v']['text']
    fecha = int(jv['data'][key]['data']['9132613660013027903']['v'])
    dt = datetime.fromtimestamp(fecha/1000).strftime('%Y-%m-%d')
    estado = jv['data'][key]['data']['9147974306013972380']['v']['v']

    results.append({'Bono': Bono, 'Fecha': dt, 'Estado': get_status_text(estado)})
    df = pd.DataFrame(results)
df
# Out:
#                                             Bono       Fecha        Estado
# 0              BONO LDI 25 MIN MUNDO #0912457055  2023-06-01  Desconectado
# 1                       DATOS SILVER #0936813845  2023-08-20  Desconectado
# 2     PAQUETE CHAT WHATSAPP INCLUIDO #0912457052  2023-06-01  Desconectado
# 3                PROMOCIÓN 3GB 1 MES #0939110902  2023-08-26  Desconectado
# 4              REDES SOCIALES LIBRE. #0939107981  2023-08-26  Desconectado
# ..                                           ...         ...           ...
# 144     Bono De 1000 SMS TD Nacional #0312492669  2019-03-31  Desconectado
# 145     PAQUETE SMART INTERNET 350MB #0090132708  2015-11-10  Desconectado
# 146                 MOVISTAR TV PLUS #0914145940  2023-06-06  Desconectado
# 147       Paq Redes Sociales 24meses #0090299545  2015-11-10  Desconectado
# 148  BONO ILIMITADO DE MOVISTAR PLAY #0936813839  2023-08-20  Desconectado
#
# [149 rows x 3 columns]

# %%
df_bono['Bono'] = df_bono['Bono'].str.lstrip('–').str.strip()
df_combinado = pd.merge(df_bono, df, how='left', on='Bono', reset_index=True)

df_combinado
# Out:
#                                        Bono tarifa_bono  \
# 0              BONO 5GB 3 MESES #1057786910        1.96
# 1            BONO B PERMANENCIA #0912457057       13.39
# 2  BONO 10GB PERMANENCIA $13.39 #0811645027       13.39
# 3            BONO D PERMANENCIA #0939107993       16.07
# 4            BONO C PERMANENCIA #0914028389       14.73
#
#                               name_t       Fecha        Estado
# 0  Tarifa de bonificación de lealtad  2024-12-27        Activo
# 1  Tarifa de bonificación de lealtad  2023-06-01  Desconectado
# 2  Tarifa de bonificación de lealtad  2022-08-27  Desconectado
# 3  Tarifa de bonificación de lealtad  2023-08-26        Activo
# 4  Tarifa de bonificación de lealtad  2023-06-05  Desconectado
